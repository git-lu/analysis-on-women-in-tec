# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('./data/Todas.las.carreras27032018.csv',parse_dates=['Año'])

# %%
df.head()
# Out:
#          Año                                Tipo de Institución  \
# 0 2010-01-01  Universidad                                   ...
# 1 2010-01-01  Universidad                                   ...
# 2 2010-01-01  Universidad                                   ...
# 3 2010-01-01  Universidad                                   ...
# 4 2010-01-01  Universidad                                   ...
#
#                           Institución  \
# 0                   Universidad CAECE
# 1     Universidad Nacional de Córdoba
# 2     Universidad Nacional de Rosario
# 3  Universidad Nacional de Río Cuarto
# 4    Universidad Nacional de San Juan
#
#                                     Unidad Académica  \
# 0                           Departamento de Sistemas
# 1       Facultad de Matemáticas, Astronomía y Física
# 2  Facultad de Ciencias Exactas, Ingeniería y Agr...
# 3  Facultad de Ciencias Exactas, Físico-Químicas ...
# 4  Facultad de Ciencias Exactas, Físicas y Naturales
#
# ...

# %%
df.drop(columns='Unnamed: 20',inplace=True)
df.dropna(axis=0,how='all',inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1713 entries, 0 to 1712
# Data columns (total 20 columns):
# Año                           1713 non-null datetime64[ns]
# Tipo de Institución           1713 non-null object
# Institución                   1713 non-null object
# Unidad Académica              1713 non-null object
# Carrera                       1713 non-null object
# Título                        1713 non-null object
# Gestión                       1713 non-null object
# Nivel de la Oferta            1713 non-null object
# Total de Estudiantes          1437 non-null object
# Estudiantes Varones           1423 non-null object
# Estudiantes Mujeres           1352 non-null float64
# Total de Nuevos Inscriptos    1161 non-null object
# Nuevos Inscriptos Varones     1153 non-null float64
# Nuevas Inscriptas Mujeres     1070 non-null float64
# Total de Reinscriptos         1384 non-null object
# Reinscriptos Varones          1369 non-null object
# ...

# %%
df.columns
df_nullcols = [
    'Total de Estudiantes',
    'Estudiantes Varones',
    'Estudiantes Mujeres',
    'Total de Nuevos Inscriptos',
    'Nuevos Inscriptos Varones',
    'Nuevas Inscriptas Mujeres',
    'Total de Reinscriptos',
    'Reinscriptos Varones',
    'Reinscriptos Mujeres',
    'Total de Egresados',
    'Egresados Varones',
    'Egresados Mujeres'
              ]
df_no_nulls = df[df_nullcols].fillna(0)
df_no_nulls.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1713 entries, 0 to 1712
# Data columns (total 12 columns):
# Total de Estudiantes          1713 non-null object
# Estudiantes Varones           1713 non-null object
# Estudiantes Mujeres           1713 non-null float64
# Total de Nuevos Inscriptos    1713 non-null object
# Nuevos Inscriptos Varones     1713 non-null float64
# Nuevas Inscriptas Mujeres     1713 non-null float64
# Total de Reinscriptos         1713 non-null object
# Reinscriptos Varones          1713 non-null object
# Reinscriptos Mujeres          1713 non-null float64
# Total de Egresados            1713 non-null float64
# Egresados Varones             1713 non-null float64
# Egresados Mujeres             1713 non-null float64
# dtypes: float64(7), object(5)
# memory usage: 174.0+ KB

# %%
df.groupby('Año')['Egresados Varones'].sum().plot()
df.groupby('Año')['Egresados Mujeres'].sum().plot()
